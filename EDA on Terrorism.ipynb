# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings

# %%
import pandas as pd

# Replace 'ISO-8859-1' with the appropriate encoding if needed
df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='ISO-8859-1')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_3512\1154606484.py:4: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('globalterrorismdb_0718dist.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.isna().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.rename(columns={
    'iyear': 'Year',
    'imonth': 'Month',
    'extended': 'Extended',
    'iday': 'Day',
    'country_txt': 'Country',
    'provstate': 'State',
    'region_txt': 'Region',
    'attacktype1_txt': 'attacktype',  # Corrected column name
    'target1': 'Target',
    'nkill': 'Killed',
    'nwound': 'Wounded',  # Corrected column name
    'summary': 'Summary',
    'gname': 'Group',
    'targettype1_txt': 'Target_type',  # Added missing comma
    'weapon_type': 'Weapon',  # Corrected column name
    'motive': 'Motive',
    'city': 'City',
    'latitude': 'Latitude',
    'longitude': 'Longitude'
}, inplace=True)

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df.head()
# Out:
#         eventid  Year  Month  Day approxdate  Extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid           Year          Month            Day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             Extended        country         region       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.isnull().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
columns_to_drop=['approxdate','resolution','related']
df=df.drop(columns_to_drop,axis=1)

# %%
df.head()
# Out:
#         eventid  Year  Month  Day  Extended  country             Country  \
# 0  197000000001  1970      7    2         0       58  Dominican Republic
# 1  197000000002  1970      0    0         0      130              Mexico
# 2  197001000001  1970      1    0         0      160         Philippines
# 3  197001000002  1970      1    0         0       78              Greece
# 4  197001000003  1970      1    0         0      101               Japan
#
#    region                       Region    State  ... nreleased  addnotes  \
# 0       2  Central America & Caribbean      NaN  ...       NaN       NaN
# 1       1                North America  Federal  ...       NaN       NaN
# 2       5               Southeast Asia   Tarlac  ...       NaN       NaN
# 3       8               Western Europe   Attica  ...       NaN       NaN
# 4       4                    East Asia  Fukouka  ...       NaN       NaN
#
#    scite1  scite2  scite3 dbsource INT_LOG  INT_IDEO  INT_MISC  INT_ANY
# ...

# %%
print(df['country'].value_counts().head(10))
# Out:
# country
# 95     24636
# 153    14368
# 4      12731
# 92     11960
# 45      8306
# 160     6908
# 159     6096
# 61      5320
# 603     5235
# 209     4292
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
country_counts = df['country'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=country_counts.index, y=country_counts.values)

plt.title('Top 15 Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(df['State'].value_counts().head(10))
# Out:
# State
# Baghdad               7645
# Northern Ireland      4498
# Unknown               4290
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
state_counts = df['State'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=state_counts.index, y=state_counts.values)

plt.title('Top 15 state Affected')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
data_istates=df[df['Country']=='India']['State']
data_istates.value_counts()[:10]
# Out:
# State
# Jammu and Kashmir    2454
# Assam                1151
# Manipur              1100
# Chhattisgarh          979
# Punjab                949
# Jharkhand             887
# Bihar                 688
# West Bengal           650
# Odisha                428
# Maharashtra           302
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
state_counts = df['State'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=state_counts.index, y=state_counts.values)

plt.title('Top 15 state Affected')
plt.xlabel('States')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(df['City'].value_counts().head(10))
# Out:
# City
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
City_counts = df['City'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=City_counts.index, y=City_counts.values)

plt.title('Top 15 City Affected')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(df['Region'].value_counts().head(10))
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
Region_counts = df['Region'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=Region_counts.index, y=Region_counts.values)

plt.title('Top 15 Region Affected')
plt.xlabel('Region')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(df['Year'].value_counts().head(15))
# Out:
# Year
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# 2009     4721
# 1991     4683
# 1989     4324
# 1990     3887
# 1988     3721
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
Year_counts = df['Year'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=Year_counts.index, y=Year_counts.values)

plt.title('Top 15 Year Affected')
plt.xlabel('Year')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
print(df['Group'].value_counts().head(10))
# Out:
# Group
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))

# Creating a bar plot with the top 15 countries and their counts
Group_counts = df['Group'].value_counts()[:15]  # Top 15 country counts
sns.barplot(x=Group_counts.index, y=Group_counts.values)

plt.title('Top 15 Group Affected')
plt.xlabel('Group')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()
